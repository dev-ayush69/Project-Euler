# %% [markdown]
# ### Problem 29 - Distint Powers
# Consider all integer combinations of a<sup>b</sup> for 2 ≤ a ≤ 5 and 2 ≤ b ≤ 5:
#
# 2<sup>2</sup>=4, 2<sup>3</sup>=8, 2<sup>4</sup>=16, 2<sup>5</sup>=32\
# 3<sup>2</sup>=9, 3<sup>3</sup>=27, 3<sup>4</sup>=81, 3<sup>5</sup>=243\
# 4<sup>2</sup>=16, 4<sup>3</sup>=64, 4<sup>4</sup>=256, 4<sup>5</sup>=1024\
# 5<sup>2</sup>=25, 5<sup>3</sup>=125, 5<sup>4</sup>=625, 5<sup>5</sup>=3125
#
# If they are then placed in numerical order, with any repeats removed, we get the following sequence of 15 distinct terms:\
# 4, 8, 9, 16, 25, 27, 32, 64, 81, 125, 243, 256, 625, 1024, 3125
#
# How many distinct terms are in the sequence generated by ab for 2 ≤ a ≤ 100 and 2 ≤ b ≤ 100?

# %% [markdown]
# ### Solution
# We generate all the numbers and store them in a set, since handling big numbers in python is cakewalk.

# %%
# Copyright 2023 - Ayush Mishra (dev-ayush69) - MacBook Air M1

def terms(n, m):
    x = [a**b for a in range(2, n+1) for b in range(2, m+1)]
    return x

def main():
    n = m = 100
    ans = len(set(terms(n, m)))
    return ans

print(main())
# Out:
# 9183
